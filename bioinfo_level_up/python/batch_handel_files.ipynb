# %% [markdown]
# ## 基础文件与文本处理

# %% [markdown]
# 目标：
# * 文件读写
# * 字符串处理
# * 正则表达式
# * 统计信息

# %%
import os
import pathlib
import re
import collections
import statistics

# %%
data_dir = pathlib.Path('../data')
text_file = data_dir / 'textfile'
# 创建文件夹
text_file.mkdir(exist_ok=True)
# 下载文本文件
url = 'https://www.gutenberg.org/files/1342/1342-0.txt'
textfile = text_file / 'pride_and_prejudice.txt'
if not textfile.exists():
    curl_command = f'curl -o {text_file / "pride_and_prejudice.txt"} {url}'
    os.system(curl_command)

# %% [markdown]
# ### 统计文本文件行数

# %%
# 统计文本文件行数
with open(textfile, 'r') as f:
    line_count = sum(1 for line in f)

# %% [markdown]
# ### 统计单词出现次数

# %% [markdown]
# ### 过滤特定后缀

# %% [markdown]
# ### 批量读取
